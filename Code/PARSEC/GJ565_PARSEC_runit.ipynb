# %%
import parsec_py3_rp_dr3 as parsec

# %%
parsec.runit("GJ565", stepnumber=2000)
# Out:
# 	GJ565
#
# 	Teff [K]: 4783.0 +/- 100.0
# 	[Fe/H]: -0.9 +/- 0.05
#
#
# 	Gmag: 7.489461421966553 +/- 0.0020102879335400555
# 	BPmag: 8.022768020629883 +/- 0.005049241143379546
# 	RPmag: 6.801604747772217 +/- 0.00304223407661151
# 	Jmag: 5.989999771118164 +/- 0.017999999225139618
# 	Hmag: 5.493000030517578 +/- 0.020999999716877937
# 	Kmag: 5.385000228881836 +/- 0.026000000536441803
#
# 	 D [pc] =  16.74431009838595  +/-  0.011250838634353652
# /home/aaron/Desktop/Second_Earth_Target_Selection/Code/PARSEC/parsec_py3_rp_dr3.py:615: RuntimeWarning: overflow encountered in double_scalars
#   ys = 10**(-0.2*(m*Av + n))
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]/home/aaron/anaconda3_new/lib/python3.9/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|███████████████████████████████████████| 2000/2000 [01:44<00:00, 19.06it/s]
# ...

# %% [markdown]
# Comments: This seems to be a very old stars right at the cut off.
