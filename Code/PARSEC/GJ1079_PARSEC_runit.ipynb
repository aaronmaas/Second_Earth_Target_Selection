# %%
import parsec_py3_rp_dr3 as parsec

# %%
parsec.runit("GJ1079", stepnumber=2000)
# Out:
# 	GJ1079
#
# 	Teff [K]: 4928.0 +/- 50.0
# 	[Fe/H]: -0.13 +/- 0.03
#
#
# 	Gmag: 7.4225544929504395 +/- 0.002005602475906772
# 	BPmag: 7.915007591247559 +/- 0.0050224926900004525
# 	RPmag: 6.767078876495361 +/- 0.0030177597102719186
# 	Jmag: 6.013999938964844 +/- 0.028999999165534973
# 	Hmag: 5.492000102996826 +/- 0.028999999165534973
# 	Kmag: 5.386000156402588 +/- 0.019999999552965164
#
# 	 D [pc] =  17.835303148115113  +/-  0.007709765715050049
#   8%|███                                     | 155/2000 [00:04<01:19, 23.18it/s]/home/aaron/Desktop/Second_Earth_Target_Selection/Code/parsec_py3_rp_dr3.py:615: RuntimeWarning: overflow encountered in double_scalars
#   ys = 10**(-0.2*(m*Av + n))
# 100%|███████████████████████████████████████| 2000/2000 [00:52<00:00, 38.00it/s]
# Please Enter BurnIn phase (previous steps in chain get discarded): 750
# (12500, 3)
#
#
# IMASS = 0.7320146686058016 ( 0.007449862356817216 0.011391416828907874 )
# AGE = 10.945702935340586 ( 2.0492761521398535 1.5535593494461057 )
# MASS = 0.7318201144828218 ( 0.007456928104878635 0.011425118063807305 )
# Teff = 4960.975711725996 ( 17.763708477448745 30.847022975464824 )
# log(g) = 4.582790805872532 ( 0.007941758269485177 0.010536315735921953 )
# Rs = 0.7243584507949152 ( 0.003870140012432244 0.0030412696070728495 )
# L = 0.2847950591872309 ( 0.004260632712606294 0.005991607613164696 )
# Rho = 2.7157994765450377 ( 0.05919519104101667 0.07983194644858616 )
# Av = 0.0383312269600367 ( 0.024386496229465007 0.036897807918537265 )

# %% [markdown]
# Comments: This seems to be a very old stars right at the cut off.
