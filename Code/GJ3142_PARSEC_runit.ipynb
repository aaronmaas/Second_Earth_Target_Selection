# %%
import numpy as np
import parsec_py3_rp_dr3 as parsec

# %%
parsec.runit("GJ3142", stepnumber=3000)
# Out:
# 	GJ3142
#
# 	Teff [K]: 3257.0 +/- 60.0
# 	[Fe/H]: 0.09 +/- 0.08
#
#
# 	Gmag: 12.096098899841309 +/- 0.0022126192513557694
# 	BPmag: 13.802005767822266 +/- 0.007152553555329815
# 	RPmag: 10.841475486755371 +/- 0.0037321970523208686
# 	Jmag: 9.055000305175781 +/- 0.029999999329447746
# 	Hmag: 8.517999649047852 +/- 0.026000000536441803
# 	Kmag: 8.168000221252441 +/- 0.020999999716877937
#
# 	 D [pc] =  15.249263816285016  +/-  0.010114900781920103
#   0%|                                                  | 0/3000 [00:00<?, ?it/s]/home/aaron/anaconda3_new/lib/python3.9/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
#   0%|                                          | 8/3000 [00:00<01:15, 39.68it/s]/home/aaron/Desktop/Second_Earth_Target_Selection/Code/parsec_py3_rp_dr3.py:615: RuntimeWarning: overflow encountered in double_scalars
#   ys = 10**(-0.2*(m*Av + n))
# 100%|███████████████████████████████████████| 3000/3000 [01:20<00:00, 37.27it/s]
# Please Enter BurnIn phase (previous steps in chain get discarded): 500
# (25000, 3)
#
#
# IMASS = 0.40002763956448545 ( 2.0635350974906874e-05 4.559383575908349e-05 )
# AGE = 0.4321916994091397 ( 0.00517197709456424 0.0068742723920588444 )
# MASS = 0.40002764532471113 ( 2.0649409332385016e-05 4.563483710040561e-05 )
# Teff = 3295.9181475566747 ( 0.037456297153312335 0.0831659096884323 )
# log(g) = 4.870985640767066 ( 7.755788236529781e-05 9.776311849396535e-05 )
# Rs = 0.38423059197781373 ( 5.121342017139208e-05 4.2940638254163055e-05 )
# L = 0.015595198373486092 ( 2.262633889896573e-06 5.077104669281088e-06 )
# Rho = 9.942047972895443 ( 0.0027808148096060137 0.0035674770604448014 )
# Av = 1.4145061374648438 ( 0.0033089238799048903 0.003395250419454321 )

# %% [markdown]
# Looks reasonable. The star is at the very low Mass end of the PARSEC isochrones.
