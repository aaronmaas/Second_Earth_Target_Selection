# %% [markdown]
# # Analysis of GJ1079 Spectra

# %% [markdown]
# ## Cleaning and Plotting data

# %% [markdown]
# In this step, we will plot all available data for the Star and also look at the Lomb Scargle Periodogram to identfy possible RV signals due to planets, companions stars or mag activity. Before this is done the blaze function is fitted to the original blaze uncorrected spectra. Please check if the provided targetname and spectra directory are correct.

# %%
star_name = 'GJ1079'
directory_name = '/home/aaron/Desktop/ZASPE/Spectra/GJ1079'

# %% [markdown]
# ## Calculate wavelength calibration from Polynomials

# %%
     
from funcs import collect_fits_files, separate_fits_files
    
fits_files = collect_fits_files(directory_name,extension="A.fits")
fits_files, ccf_files = separate_fits_files(fits_files)
    
from funcs import calculate_wavelengths 

wavelengths = calculate_wavelengths(fits_files, directory_name)
observed_wavelengths = wavelengths
# Out:
# Shape of wavelengths array: (79, 72, 4096)

# %% [markdown]
# ### Apply the blaze correction by fitting a Polynomial to Blaze Uncorrected Spectra

# %%
   
from funcs import apply_blaze_correction

discarded_nights = apply_blaze_correction(observed_wavelengths,fits_files,ccf_files,directory_name)
# Out:
#   0%|          | 0/79 [00:00<?, ?it/s]
# WARNING: VerifyWarning: Keyword name 'SPEC_NAME' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]
# WARNING: VerifyWarning: Keyword name 'NUM_ORDERS' is greater than 8 characters or contains characters not allowed by the FITS standard; a HIERARCH card will be created. [astropy.io.fits.card]

# %%
#remove nights to be discarded
import numpy as np
if len(discarded_nights) != 0:
    wavelenghts = np.delete(wavelengths,discarded_nights,axis = 0)
    fits_files = [fits_file for i, fits_file in enumerate(fits_files) if i not in discarded_nights]
    ccf_files = [ccf_file for i, ccf_file in enumerate(ccf_files) if i not in discarded_nights]  
    
    
#collect all fits files in the given directory
fits_files = collect_fits_files(directory_name, extension = 'blaze_correction.fits')

# %% [markdown]
# ### Plot the blaze corrected spectra

# %% [markdown]
# The the step takes long due to extensive plotting. The .png files are stored in Plots/star_name_observer_night.png. The star name is obtained from simbad. Default is Gliese catalog, if not available it will use Henry Draper and otherwise Tess Input. \ You do not have to run the next 2 cells as it takes long. However, if you are interested in how the spectra look, you might want to take a peak.

# %%
from funcs import plot_arrays, query_tic_name,query_gliese_name,query_HD_name, extract_target_info, extract_target_info_astropy
import matplotlib.pyplot as plt
from astropy.io import fits 
from tqdm.notebook import tqdm
from time import sleep
import re

for i in tqdm(range(len(fits_files))): 
    spectrum = fits.getdata(fits_files[i])
    flux = spectrum[3,:] #CERES pipeline blaze corrected flux
    wavelength = spectrum[0,:]
    string = fits_files[i] 
    cut_string = string.split("/")[-1][:38] + ".png"
    
    target_name, observed_night = extract_target_info_astropy(fits_files[i])
    t1 = target_name 
    if target_name.startswith("GJ") == False:
        target_name = query_gliese_name(target_name)    #try to get gliese id
    if target_name == "Unknown":
        target_name = query_HD_name(t1)   #try to get HD id
    if target_name == "Unknown":
        target_name = query_tic_name(t1) # try to get TIC id
      
      
    #make sure there is no whitespaces in the target_name
    pattern = re.compile(r'\s+')
    target_name = re.sub(pattern, '', target_name)
    
    file_name = target_name + observed_night + ".png"
    save_dir = "Plots/" + target_name
    
    plot_arrays(flux,wavelength,save_dir=save_dir, save_filename=file_name)
    
    sleep(3)

# %%
#example plot
#add the file you intend to show
example_file = save_dir + "/" + file_name
from IPython.display import display, Image
display(Image(filename=example_file))

# %% [markdown]
# ### RV Analyis

# %%
from funcs import get_RV_BJD
#obtain RV, RV uncertainty and BJD from the CCFs 
rv, rv_err, bjd = get_RV_BJD(ccf_files)

# %%
#plotting the RV variation
from funcs import plot_rvs

save_dir = 'Plots/' + star_name 
file_name = star_name + "_RV_variation.png"
plot_rvs(rv,rv_err/1000, bjd,save_dir, file_name)

# %%
# %matplotlib notebook
#plotting the LS Periodogram
from funcs import plot_lomb_scargle

file_name = star_name + "_Lomb_Scargle.png"
plot_lomb_scargle(bjd, rv, rv_err/1000, save_dir= save_dir, save_filename=file_name)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# Comments: Big Peak befor 500 days.

# %% [markdown]
# ## Combine and Align Spectra

# %% [markdown]
# In this step, we will combine and align all available spectra in the same time frame while removing artifacts that we dont want to have in the combined spectra, like saturation or cosmic rays. We will use two methods to combine the spectra - RV - correction method and Cross-Correlation Method.

# %% [markdown]
# ### RV correction method

# %% [markdown]
# The RV correction is performed using the measured RVs by Harps. The wavelengths are then corrected for RV shift due to different time frames and moved to the first obervation night.

# %%
  
import scipy.constants as c

c_km = c.c/1000 
    
    
# %matplotlib notebook
from funcs import plot_fluxes, plot_median_spectrum, interpolate_flux, get_wavelength_flux_RV, save_spectrum_as_text 

#get fit files
filelist = fits_files

#get observed wavelength, flux and eflux; extract RV and calculate corrected wavelength
wave, flux, eflux, RV, BERV, wave_corr, combined_orders = get_wavelength_flux_RV(filelist, ceres = False)

#get reference wavelength from first observation night 
wave_ref_corr = wave[0] / (1 + RV[0] / c_km) 

#interpolate flux at corrected wavelength and on the corrected wavelegnths reference
flux_interp = interpolate_flux(wave, flux, wave_ref_corr, RV, BERV)

#median flux for specific order
flux_median = np.median(flux_interp, axis=0)

#controll plots for specific order
norder = 35 
plot_fluxes(wave_corr, flux, norder) 
plot_median_spectrum(wave_ref_corr, flux_median+3000, norder)   

#save the spectrum as txt file for ZASPE
save_directory = "Spectra/" + star_name 
file_name = star_name + "_RV_method.txt"
save_spectrum_as_text(combined_orders, wave_ref_corr, flux_median, save_directory, file_name)
# Out:
# Night 76 in Order 0 has been discarded due to non-contributing flux.
# Night 62 in Order 1 has been discarded due to non-contributing flux.
# Night 32 in Order 2 has been discarded due to non-contributing flux.
# Night 76 in Order 2 has been discarded due to non-contributing flux.
# Night 32 in Order 3 has been discarded due to non-contributing flux.
# Night 76 in Order 3 has been discarded due to non-contributing flux.
# Night 32 in Order 4 has been discarded due to non-contributing flux.
# Night 76 in Order 4 has been discarded due to non-contributing flux.
# Night 32 in Order 5 has been discarded due to non-contributing flux.
# Night 76 in Order 5 has been discarded due to non-contributing flux.
# Night 76 in Order 6 has been discarded due to non-contributing flux.
# Night 76 in Order 8 has been discarded due to non-contributing flux.
# Night 32 in Order 14 has been discarded due to non-contributing flux.
# Night 32 in Order 19 has been discarded due to non-contributing flux.
# Night 32 in Order 30 has been discarded due to non-contributing flux.
# Night 32 in Order 31 has been discarded due to non-contributing flux.
# Night 32 in Order 32 has been discarded due to non-contributing flux.
# Night 32 in Order 33 has been discarded due to non-contributing flux.
# Night 32 in Order 34 has been discarded due to non-contributing flux.
# Night 32 in Order 35 has been discarded due to non-contributing flux.
# Night 32 in Order 38 has been discarded due to non-contributing flux.
# Night 32 in Order 39 has been discarded due to non-contributing flux.
# Night 32 in Order 40 has been discarded due to non-contributing flux.
# Night 32 in Order 41 has been discarded due to non-contributing flux.
# Night 32 in Order 42 has been discarded due to non-contributing flux.
# Night 32 in Order 46 has been discarded due to non-contributing flux.
# Night 32 in Order 49 has been discarded due to non-contributing flux.
# Night 32 in Order 50 has been discarded due to non-contributing flux.
# Night 32 in Order 52 has been discarded due to non-contributing flux.
# Night 32 in Order 54 has been discarded due to non-contributing flux.
# Night 32 in Order 55 has been discarded due to non-contributing flux.
# Night 32 in Order 59 has been discarded due to non-contributing flux.
# Night 32 in Order 64 has been discarded due to non-contributing flux.
# Night 32 in Order 69 has been discarded due to non-contributing flux.
# Night 32 in Order 70 has been discarded due to non-contributing flux.
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ### Cross-correlation method

# %% [markdown]
# The cross-correlation method takes the median flux from the RV method as star templat to correlate with. It then performes combines and alignes the spectra via cross correlation to the reference template. At the moment there are some issus with the cc method why using only RV method is recommended. In principle should the RV method result in the most accurate shift to the assigned reference spectrum.

# %%
    
from funcs import align_spectra
from funcs import combine_spectra
from astropy.io import fits 
import matplotlib.pyplot as plt

num_orders = np.shape(fits.getdata(fits_files[0]))[1]

#template is the RV corrected version
template = flux_median 

#Specify the spectral order to combine
combined_spectra = []
for i in range(num_orders):
    combined_spectrum = combine_spectra(fits_files, i, template, blaze_corrected=True)
    combined_spectra.append(np.array(combined_spectrum))

combined_spectra = np.array(combined_spectra)
# Out:
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 0 has been discarded due to significant deviation. Median value 39.87606415741212
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-02-10T03:04:46.207_blaze_correction.fits in order 1 has been discarded due to significant deviation. Median value 2490.7610456943285
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 2 has been discarded due to significant deviation. Median value 132.51420486364717
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 2 has been discarded due to significant deviation. Median value 102.87613945765423
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 3 has been discarded due to significant deviation. Median value 148.73665064568695
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 3 has been discarded due to significant deviation. Median value 92.87545863894142
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 4 has been discarded due to significant deviation. Median value 157.40698588751997
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 4 has been discarded due to significant deviation. Median value 112.11068288020476
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 5 has been discarded due to significant deviation. Median value 204.179814141679
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 5 has been discarded due to significant deviation. Median value 143.0066237740075
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 6 has been discarded due to significant deviation. Median value 223.13811580463698
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2016-09-30T08:53:34.388_blaze_correction.fits in order 8 has been discarded due to significant deviation. Median value 505.3942406034005
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 14 has been discarded due to significant deviation. Median value 1127.6644192288977
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 15 has been discarded due to significant deviation. Median value 1162.0000488320425
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 16 has been discarded due to significant deviation. Median value 1215.1775046666103
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 18 has been discarded due to significant deviation. Median value 1356.9665655873941
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 19 has been discarded due to significant deviation. Median value 1283.3309244788688
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 21 has been discarded due to significant deviation. Median value 1939.7412586052292
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 22 has been discarded due to significant deviation. Median value 1923.182490103094
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 27 has been discarded due to significant deviation. Median value 3047.8111512925707
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 28 has been discarded due to significant deviation. Median value 3162.032226598944
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 29 has been discarded due to significant deviation. Median value 3352.321683826387
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 30 has been discarded due to significant deviation. Median value 3423.616937667495
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 31 has been discarded due to significant deviation. Median value 3388.473833260303
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 32 has been discarded due to significant deviation. Median value 3679.199396426802
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 33 has been discarded due to significant deviation. Median value 3616.537185314786
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 34 has been discarded due to significant deviation. Median value 3967.5005137103717
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 35 has been discarded due to significant deviation. Median value 3875.743347406072
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 36 has been discarded due to significant deviation. Median value 4182.063869819792
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 37 has been discarded due to significant deviation. Median value 4320.215298318177
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 38 has been discarded due to significant deviation. Median value 4562.258312719236
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 39 has been discarded due to significant deviation. Median value 4355.538948739826
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 40 has been discarded due to significant deviation. Median value 4626.026938598265
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 41 has been discarded due to significant deviation. Median value 4596.921246726311
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 42 has been discarded due to significant deviation. Median value 4833.64335390136
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 43 has been discarded due to significant deviation. Median value 4270.184360873582
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 44 has been discarded due to significant deviation. Median value 5454.4163849881215
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 45 has been discarded due to significant deviation. Median value 5733.287849309647
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 46 has been discarded due to significant deviation. Median value 6025.071826048914
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 47 has been discarded due to significant deviation. Median value 6251.031759216794
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 48 has been discarded due to significant deviation. Median value 6584.228072555534
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 49 has been discarded due to significant deviation. Median value 6698.374912433908
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 50 has been discarded due to significant deviation. Median value 6913.302663927327
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 51 has been discarded due to significant deviation. Median value 7012.859834498808
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 52 has been discarded due to significant deviation. Median value 7310.843182265533
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 53 has been discarded due to significant deviation. Median value 7511.501707140597
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 54 has been discarded due to significant deviation. Median value 7509.407233665026
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 55 has been discarded due to significant deviation. Median value 7909.150791442551
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 56 has been discarded due to significant deviation. Median value 7616.712118849033
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 58 has been discarded due to significant deviation. Median value 8049.4857285005355
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 59 has been discarded due to significant deviation. Median value 8130.133284795356
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 60 has been discarded due to significant deviation. Median value 8363.301045943263
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 61 has been discarded due to significant deviation. Median value 8504.922329468973
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 63 has been discarded due to significant deviation. Median value 8555.35973021933
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 64 has been discarded due to significant deviation. Median value 8582.518932091349
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 65 has been discarded due to significant deviation. Median value 8698.59774648991
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 66 has been discarded due to significant deviation. Median value 8470.693027351
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 68 has been discarded due to significant deviation. Median value 8558.601350808458
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 69 has been discarded due to significant deviation. Median value 8128.143084331104
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 70 has been discarded due to significant deviation. Median value 7946.198685442334
# Spectrum from night /home/aaron/Desktop/ZASPE/Spectra/GJ1079/HARPS2013-12-03T06:31:02.358_blaze_correction.fits in order 71 has been discarded due to significant deviation. Median value 7279.077383720731

# %%
# %matplotlib notebook 

import matplotlib.pyplot as plt 
plt.xlabel(r"Wavelength $[A]$")
plt.ylabel(r"Flux")
for i in range(len(combined_spectra[:,1])):
    plt.plot(combined_spectra[:,1][i], combined_spectra[:,2][i])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
    
from funcs import store_spectrum_orders
save_dir = "Spectra/" + star_name + "/"

#Cross correlation method    
file_name = star_name + "_CCM" + ".txt"

store_spectrum_orders(combined_spectra[:,1],combined_spectra[:,2], save_dir = save_dir, file_name = file_name )
# Out:
# The spectrum for all orders has been stored in the file: Spectra/GJ1079/GJ1079_CCM.txt
