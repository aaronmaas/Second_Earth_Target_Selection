# %%
import matplotlib.pyplot as plt
import numpy as np 
from astropy.io import fits

# %%
hdul = fits.open('data', ignore_missing_simple = True)

# %%
hdul.info()
# Out:
# Filename: data
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     714   (4296, 4096)   uint16

# %%
hdul[0].data[0]
# Out:
# array([188, 192, 194, ..., 215, 194, 241], dtype=uint16)

# %%
# %matplotlib notebook
plt.plot(hdul[0].data[0])
# Out:
# <img src="data:image/png;base64,..." width="640">
